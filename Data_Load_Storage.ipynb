# %% [markdown]
# <a href="https://colab.research.google.com/github/leandrobarbieri/pydata-book/blob/2nd-edition/Data_Load_Storage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de Dados
# Exmplos de diversos formatos de fonte de dados e tipos de manipulações que podem ser feitas logo no início

# %%
# importações e configurações iniciais
import numpy as np
import pandas as pd

# padronização da aleatoriedade do metodo randomico para garantir reprodutbilidade
np.random.seed(12345)

# Confgurações da matplotlib.pyplot
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# tamanho da tabela de exibição do dataframe
pd.options.display.max_rows = 10

# %% [markdown]
# ## CSV
# Importando dados em arquivos do tipo csv.
# - sep=: define o separados usado, padrão é , ou ;
# - header=: Define se a primeira linha será o cabeçalho
# - encoding=: tipo de codificação do arquivo
# - nrows=: a quantidade de linhas máxima que serão lidas
# - skiprows=: lista de indices de linhas que serão ignoradas na carga
# - names=: lista de nomes de colunas para as colunas carregadas (se já vier coluna, devemos ignorar a primeira linha[1:])
# - index_col: se False será criado um index auto, senão, podemos escolher quais colunas usar como indice nomeado
# - na_values: lista de valores que se encontrados nas colunas serão transformados em NaN
# - error_bad_lines=: elimina da carga as linhas que não se encaixam no formato esperado
# - on_bad_lines {‘error’, ‘warn’, ‘skip’}, default ‘error’. Define o que fazer quando a linha retorna erro por não ser possível ser carregada
# - chunksize=: quebra o arquivo grante em partes que podem ser iteradas

# %% [markdown]
# ### Leitura CSV

# %%
# arquivos csv
url = "https://bi.s3.es.gov.br/covid19/MICRODADOS_BAIRROS.csv"

# Em alguns casos é necessário definir explicitamente o separador e o tipo de encode que o arquivo está
dados_covid_bairros = pd.read_csv(url, sep=",", encoding="latin1", nrows=10000, error_bad_lines=False)
dados_covid_bairros
# Out:
# b'Skipping line 1210: expected 9 fields, saw 10\n'
#               Bairros    Municipios  ... Suspeitos  Descartados
# 0      Não Encontrado         SERRA  ...       528        37972
# 1      JARDIM CAMBURI       VITORIA  ...      5983        14004
# 2      PRAIA DA COSTA    VILA VELHA  ...      4455         7490
# 3     JARDIM DA PENHA       VITORIA  ...      4196         7631
# 4      Não Encontrado     CARIACICA  ...      1498        11836
# ...               ...           ...  ...       ...          ...
# 6496    Não Informado    LAGO NORTE  ...         0            0
# 6497    Não Informado         GUARA  ...         0            0
# 6498     RUA COLATINA  NOVA VENECIA  ...         0            0
# 6499    Não Informado     CEILANDIA  ...         0            0
# 6500    Não Informado      TRINDADE  ...         0            0
#
# [6501 rows x 9 columns]

# %%
# Header: Não usa a primeira linha como cabeçalho
# [1:] desconsidera a primeira linha. O padrão para header é inferir a partir dos valores da primieira linha os nomes das colunas
dados_covid_bairros_sem_header = pd.read_csv(url, sep=",", encoding="latin1", error_bad_lines=False, nrows=1000, header=None)[1:]
dados_covid_bairros_sem_header
# Out:
#                         0           1               2  ...     6     7      8
# 1          Não Encontrado       SERRA  Espírito Santo  ...    13   528  37972
# 2          JARDIM CAMBURI     VITORIA  Espírito Santo  ...  8830  5983  14004
# 3          PRAIA DA COSTA  VILA VELHA  Espírito Santo  ...  7170  4455   7490
# 4         JARDIM DA PENHA     VITORIA  Espírito Santo  ...  4914  4196   7631
# 5          Não Encontrado   CARIACICA  Espírito Santo  ...  1373  1498  11836
# ..                    ...         ...             ...  ...   ...   ...    ...
# 995             JABAQUARA    ANCHIETA  Espírito Santo  ...   114    37    225
# 996  PAUL DE GRAÇA ARANHA    COLATINA  Espírito Santo  ...   111    66    194
# 997                 PORTO  SAO MATEUS  Espírito Santo  ...    55   149    171
# 998       VILA GUARANHUNS  VILA VELHA  Espírito Santo  ...   114   113    155
# 999        PARQUE GRAMADO   CARIACICA  Espírito Santo  ...   108   108    157
#
# [999 rows x 9 columns]

# %%
# Nomes das colunas: define lista customizada de nomes para as colunas (names=)
# Indice das linhas: index_col=False. Força a definição de um indice inteiros ao inves de criar o indice de linhas usando a primeira coluna
dados_covid_bairros_com_header_customizado = pd.read_csv(url, sep=",", encoding="latin1", 
                                                         error_bad_lines=False, nrows=1000,
                                                         names=["LOCAL", "DISTRITO", "UF", "CASOS", "OB", "CUR", "SUSP", "DESC"],
                                                         index_col=False,
                                                         )[1:]
dados_covid_bairros_com_header_customizado
# Out:
#                     LOCAL    DISTRITO              UF  ...  CUR  SUSP  DESC
# 1          Não Encontrado       SERRA  Espírito Santo  ...    4    13   528
# 2          JARDIM CAMBURI     VITORIA  Espírito Santo  ...  114  8830  5983
# 3          PRAIA DA COSTA  VILA VELHA  Espírito Santo  ...  152  7170  4455
# 4         JARDIM DA PENHA     VITORIA  Espírito Santo  ...   89  4914  4196
# 5          Não Encontrado   CARIACICA  Espírito Santo  ...   19  1373  1498
# ..                    ...         ...             ...  ...  ...   ...   ...
# 995             JABAQUARA    ANCHIETA  Espírito Santo  ...    3   114    37
# 996  PAUL DE GRAÇA ARANHA    COLATINA  Espírito Santo  ...    2   111    66
# 997                 PORTO  SAO MATEUS  Espírito Santo  ...    3    55   149
# 998       VILA GUARANHUNS  VILA VELHA  Espírito Santo  ...    0   114   113
# 999        PARQUE GRAMADO   CARIACICA  Espírito Santo  ...    3   108   108
#
# [999 rows x 8 columns]

# %%
# Indices com as colunas existentes: usando uma das colunas ou várias para criar um indice das linhas
dados_covid_bairros_indice_alternativo = pd.read_csv(url, sep=",", encoding="latin1", nrows=1000,
                                                     error_bad_lines=False, 
                                                     index_col=["Bairros", "Municipios", "Estado"])[1:]
dados_covid_bairros_indice_alternativo
# Out:
#                                                 Notificacoes  ...  Descartados
# Bairros              Municipios Estado                        ...
# JARDIM CAMBURI       VITORIA    Espírito Santo         28983  ...        14004
# PRAIA DA COSTA       VILA VELHA Espírito Santo         19273  ...         7490
# JARDIM DA PENHA      VITORIA    Espírito Santo         16850  ...         7631
# Não Encontrado       CARIACICA  Espírito Santo         14796  ...        11836
#                      VITORIA    Espírito Santo         14069  ...        13162
# ...                                                      ...  ...          ...
# PAUL DE GRAÇA ARANHA COLATINA   Espírito Santo           383  ...          194
# PORTO                SAO MATEUS Espírito Santo           382  ...          171
# VILA GUARANHUNS      VILA VELHA Espírito Santo           382  ...          155
# PARQUE GRAMADO       CARIACICA  Espírito Santo           382  ...          157
# BOULEVARD LAGOA      SERRA      Espírito Santo           382  ...          211
#
# [999 rows x 6 columns]

# %%
# Aplicando alguns filtros para não carregar linhas indesajadas
# skiprows: define os índices das linhas que não serão carregadas
# isso pode ajudar no processo de limpeza de arquivos que trazem linhas adicinais com comentários
# skipfooter: ignora algumas linhas no final (não pode ser usada em conjunto com nrows)
# skip_blank_lines: ignora linhas em branco ao inves de aplicar NaN
dados_ignorar_linhas_especificas = pd.read_csv(url, encoding="latin1", error_bad_lines=False, nrows=1000, skiprows=[0, 2, 4, 5, 6], skip_blank_lines=True)
dados_ignorar_linhas_especificas
# Out:
#          Não Encontrado             SERRA  Espírito Santo  ...    13   528  37972
# 0        PRAIA DA COSTA        VILA VELHA  Espírito Santo  ...  7170  4455   7490
# 1        Não Encontrado        VILA VELHA  Espírito Santo  ...  1378   766   9790
# 2    PRAIA DE ITAPARICA        VILA VELHA  Espírito Santo  ...  4123  2515   4744
# 3            INTERLAGOS          LINHARES  Espírito Santo  ...  3310  1622   5992
# 4        PRAIA DO CANTO           VITORIA  Espírito Santo  ...  3769  1915   5235
# ..                  ...               ...             ...  ...   ...   ...    ...
# 995         BOA VISTA I           JAGUARE  Espírito Santo  ...   118    27    232
# 996          VALPARAISO         CARIACICA  Espírito Santo  ...    83   107    184
# 997             JARDINS           ARACRUZ  Espírito Santo  ...   116    21    239
# 998            SOBREIRO  LARANJA DA TERRA  Espírito Santo  ...    94     1    283
# 999            PALMITAL           JAGUARE  Espírito Santo  ...   120    32    220
#
# [1000 rows x 9 columns]

# %%
# Pré-tratamento de linhas com valores que devem ser considarados como NaN
# na_values: captura valores específicos que são convertidos para NaN. Identifica "Não Encontrado" e converte para NaN
dados_identificar_na_values = pd.read_csv(url, encoding="latin1", error_bad_lines=False, nrows=1000, na_values=["Não Encontrado"])
dados_identificar_na_values
# Out:
#                   Bairros  Municipios  ... Suspeitos  Descartados
# 0                     NaN       SERRA  ...       528        37972
# 1          JARDIM CAMBURI     VITORIA  ...      5983        14004
# 2          PRAIA DA COSTA  VILA VELHA  ...      4455         7490
# 3         JARDIM DA PENHA     VITORIA  ...      4196         7631
# 4                     NaN   CARIACICA  ...      1498        11836
# ..                    ...         ...  ...       ...          ...
# 995  PAUL DE GRAÇA ARANHA    COLATINA  ...        66          194
# 996                 PORTO  SAO MATEUS  ...       149          171
# 997       VILA GUARANHUNS  VILA VELHA  ...       113          155
# 998        PARQUE GRAMADO   CARIACICA  ...       108          157
# 999       BOULEVARD LAGOA       SERRA  ...        31          211
#
# [1000 rows x 9 columns]

# %%
# lista os campos e os valores que serão transformados em NaN
sentinelas = {"Bairros": ["Não Encontrado", "Indefinido"], "Municipios": ["Não Encontrado", "UMBURATIBA"]}

# na_values: identifica os valores que serão transformados em NaN
dados_identificar_na_values = pd.read_csv(url, encoding="latin1", error_bad_lines=False, nrows=1000, na_values=sentinelas)
dados_identificar_na_values
# Out:
#                   Bairros  Municipios  ... Suspeitos  Descartados
# 0                     NaN       SERRA  ...       528        37972
# 1          JARDIM CAMBURI     VITORIA  ...      5983        14004
# 2          PRAIA DA COSTA  VILA VELHA  ...      4455         7490
# 3         JARDIM DA PENHA     VITORIA  ...      4196         7631
# 4                     NaN   CARIACICA  ...      1498        11836
# ..                    ...         ...  ...       ...          ...
# 995  PAUL DE GRAÇA ARANHA    COLATINA  ...        66          194
# 996                 PORTO  SAO MATEUS  ...       149          171
# 997       VILA GUARANHUNS  VILA VELHA  ...       113          155
# 998        PARQUE GRAMADO   CARIACICA  ...       108          157
# 999       BOULEVARD LAGOA       SERRA  ...        31          211
#
# [1000 rows x 9 columns]

# %%
# Lendo nrows=5 somente as primeiras linhas
dados_nrows = pd.read_csv(url, encoding="latin1", nrows=5)
dados_nrows.shape
# Out:
# (5, 9)

# %%
# ARQUIVOS GRANDES: iterando em partes
# Quebrando arquivos grandes em partes menores para otimizar a leitura e fazer com que seja possível 
# Encaixar no tamanho de memória disponivel
# Retorna um TextFileReader, que pode ser iterado para depois criar um dataframe
dados_chunker = pd.read_csv("/content/ex6.csv", chunksize=1000)

dados_list = []

for cnk in dados_chunker:  
  dados_list.append(cnk)

df_cnk = pd.concat(dados_list)
df_cnk.shape
# Out:
# (10000, 5)

# %% [markdown]
# ### Saída CSV

# %%
# gera um csv de saida index=False (desconsidera a coluna que representa o indice) e hearder=False não inclui a linha de cabeçalho
df_cnk[["key", "one"]].to_csv("/content/ex6_saida.csv", index=False, header=False)

# %%
# define novos nomes para as colunas de cabeçalhos
df_cnk[["key", "one"]].to_csv("/content/ex6_saida2.csv", index=False, header=["Chave", "UM"])

# %% [markdown]
# ## SQL Server

# %%
## Acessando dados do SQL Server
## Para funcionar precisamos estar na rede onde o banco está acessível
"""import pyodbc
import pandas as pd

server = 'DCSRVDSDBBI' 
database = 'DW_ESUSVS' 
username = 'DW_Prodest' 
password = 'MEgt9q1R4b'  
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

query = "SELECT top 1000 * FROM FactCovid19s;"
df = pd.read_sql(query, cnxn)

df["Evolucao"].value_counts()
"""
# Out:
# 'import pyodbc\nimport pandas as pd\n\nserver = \'DCSRVDSDBBI\' \ndatabase = \'DW_ESUSVS\' \nusername = \'DW_Prodest\' \npassword = \'MEgt9q1R4b\'  \ncnxn = pyodbc.connect(\'DRIVER={SQL Server};SERVER=\'+server+\';DATABASE=\'+database+\';UID=\'+username+\';PWD=\'+ password)\ncursor = cnxn.cursor()\n\nquery = "SELECT top 1000 * FROM FactCovid19s;"\ndf = pd.read_sql(query, cnxn)\n\ndf["Evolucao"].value_counts()\n'

# %% [markdown]
# ## JSON

# %%
# criando manualmente uma string que representa um obj json
obj_json = """
{"nome": "Leandro",
 "lugares": ["Brasil", "Argentina", "Mexico"],
 "animais": ["cao", "gato"],
 "familia": [ {"nome": "Breno", "idade": "3", "animais": ["Papagaio", "piriquito"]},
               {"nome": "Bruna", "idade": "34", "animais": null} ]
}
"""

# %%
# importando o modulo json e carregando a string para o formato json válido
import json

# paga uma string e retorna um obj json
resultado = json.loads(obj_json)
resultado
# Out:
# {'animais': ['cao', 'gato'],
#  'familia': [{'animais': ['Papagaio', 'piriquito'],
#    'idade': '3',
#    'nome': 'Breno'},
#   {'animais': None, 'idade': '34', 'nome': 'Bruna'}],
#  'lugares': ['Brasil', 'Argentina', 'Mexico'],
#  'nome': 'Leandro'}

# %%
# pega um json e retorna uma string 
asjson = json.dumps(resultado)
asjson
# Out:
# '{"nome": "Leandro", "lugares": ["Brasil", "Argentina", "Mexico"], "animais": ["cao", "gato"], "familia": [{"nome": "Breno", "idade": "3", "animais": ["Papagaio", "piriquito"]}, {"nome": "Bruna", "idade": "34", "animais": null}]}'

# %%
# extraindo um dataframe do obj json
familia = pd.DataFrame(resultado["familia"], columns=["nome", "idade", "animais"])
familia
# Out:
#     nome idade                animais
# 0  Breno     3  [Papagaio, piriquito]
# 1  Bruna    34                   None

# %%
# importando a biblioteca para fazer requisições url
from urllib.request import urlopen

# %%
url = 'https://dados.es.gov.br/api/3/action/datastore_search?resource_id=be244972-a13e-4b0f-a1f2-bced9d5f4b01&limit=1000'  

# resposta da url
conteudo_url = urlopen(url)

# exibe o header da requisição http
print(conteudo_url.headers)

# le o conteudo da requisição http
dados_url = conteudo_url.read()
print(f"Conteúdo bruto da requisição http:\n {dados_url}\n")

# transforma a string do conteúdo no formato json par um obj do tipo json
obj_json2 = json.loads(dados_url)

# acessando os atributos json
obj_json2["result"]["fields"]
obj_json2["result"]["records"]

linhas = pd.DataFrame(resultado3["result"]["records"])
print(f"Shape: {linhas.shape }\n")

linhas
# Out:
# Cache-Control: private
# Keep-Alive: timeout=5, max=99
# Content-Length: 98690
# Content-Type: application/json;charset=utf-8
# Server: Microsoft-IIS/10.0
# X-Powered-By: ARR/3.0
# Date: Fri, 30 Jul 2021 21:40:32 GMT
# Connection: close
#
#
# Conteúdo bruto da requisição http:
#  b'{"help": "https://dados.es.gov.br/api/3/action/help_show?name=datastore_search", "success": true, "result": {"include_total": true, "resource_id": "be244972-a13e-4b0f-a1f2-bced9d5f4b01", "fields": [{"type": "int", "id": "_id"}, {"type": "timestamp", "id": "data"}, {"type": "text", "id": "praca"}, {"type": "numeric", "id": "categoria_1"}, {"type": "numeric", "id": "categoria_2"}, {"type": "numeric", "id": "categoria_3"}, {"type": "numeric", "id": "categoria_4"}, {"type": "numeric", "id": "categoria_5"}, {"type": "numeric", "id": "categoria_6"}, {"type": "numeric", "id": "categoria_7"}, {"type": "numeric", "id": "categoria_8"}, {"type": "numeric", "id": "categoria_88"}, {"type": "numeric", "id": "categoria_9"}, {"type": "numeric", "id": "veiculosDia"}, {"type": "text", "id": "valorDia"}, {"type": "numeric", "id": "Id"}], "records_format": "objects", "records": [{"_id":1,"data":"2020-01-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":21794,"categoria_2":185,"categoria_3":55,"categoria_4":73,"categoria_5":2,"categoria_6":37,"categoria_7":10,"categoria_8":8,"categoria_88":274,"categoria_9":1072,"veiculosDia":23510,"valorDia":"208876,5000","Id":32940},{"_id":2,"data":"2020-02-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":21630,"categoria_2":437,"categoria_3":82,"categoria_4":130,"categoria_5":6,"categoria_6":59,"categoria_7":19,"categoria_8":21,"categoria_88":328,"categoria_9":1002,"veiculosDia":23714,"valorDia":"215145,0000","Id":32941},{"_id":3,"data":"2020-03-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":19721,"categoria_2":504,"categoria_3":69,"categoria_4":173,"categoria_5":7,"categoria_6":65,"categoria_7":27,"categoria_8":27,"categoria_88":347,"categoria_9":685,"veiculosDia":21625,"valorDia":"199651,5000","Id":32942},{"_id":4,"data":"2020-04-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":18643,"categoria_2":310,"categoria_3":65,"categoria_4":153,"categoria_5":12,"categoria_6":41,"categoria_7":11,"categoria_8":19,"categoria_88":254,"categoria_9":616,"veiculosDia":20124,"valorDia":"183694,5000","Id":32943},{"_id":5,"data":"2020-05-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":21360,"categoria_2":212,"categoria_3":86,"categoria_4":110,"categoria_5":8,"categoria_6":35,"categoria_7":8,"categoria_8":13,"categoria_88":246,"categoria_9":802,"veiculosDia":22880,"valorDia":"205690,5000","Id":32944},{"_id":6,"data":"2020-06-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":15240,"categoria_2":396,"categoria_3":66,"categoria_4":147,"categoria_5":5,"categoria_6":71,"categoria_7":29,"categoria_8":34,"categoria_88":375,"categoria_9":867,"veiculosDia":17230,"valorDia":"157846,5000","Id":32945},{"_id":7,"data":"2020-07-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":13456,"categoria_2":452,"categoria_3":50,"categoria_4":161,"categoria_5":3,"categoria_6":64,"categoria_7":29,"categoria_8":49,"categoria_88":420,"categoria_9":787,"veiculosDia":15471,"valorDia":"143437,5000","Id":32946},{"_id":8,"data":"2020-08-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":14201,"categoria_2":454,"categoria_3":50,"categoria_4":170,"categoria_5":6,"categoria_6":67,"categoria_7":31,"categoria_8":43,"categoria_88":387,"categoria_9":887,"veiculosDia":16296,"valorDia":"150700,5000","Id":32947},{"_id":9,"data":"2020-09-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":15225,"categoria_2":495,"categoria_3":63,"categoria_4":157,"categoria_5":1,"categoria_6":70,"categoria_7":34,"categoria_8":44,"categoria_88":435,"categoria_9":1020,"veiculosDia":17544,"valorDia":"161212,5000","Id":32948},{"_id":10,"data":"2020-10-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":20153,"categoria_2":506,"categoria_3":101,"categoria_4":195,"categoria_5":5,"categoria_6":57,"categoria_7":29,"categoria_8":37,"categoria_88":409,"categoria_9":1072,"veiculosDia":22564,"valorDia":"206113,5000","Id":32949},{"_id":11,"data":"2020-11-01T00:00:00","praca":"PRAIA DO SOL","categoria_1":21878,"categoria_2":382,"categoria_3":92,"categoria_4":156,"categoria_5":14,"categoria_6":47,"c ...
#
# Shape: (335, 16)
#      _id                 data           praca  ...  veiculosDia     valorDia     Id
# 0      1  2020-01-01T00:00:00    PRAIA DO SOL  ...        23510  208876,5000  32940
# 1      2  2020-02-01T00:00:00    PRAIA DO SOL  ...        23714  215145,0000  32941
# 2      3  2020-03-01T00:00:00    PRAIA DO SOL  ...        21625  199651,5000  32942
# 3      4  2020-04-01T00:00:00    PRAIA DO SOL  ...        20124  183694,5000  32943
# 4      5  2020-05-01T00:00:00    PRAIA DO SOL  ...        22880  205690,5000  32944
# ..   ...                  ...             ...  ...          ...          ...    ...
# 330  331  2020-12-27T00:00:00  TERCEIRA PONTE  ...        25089   50950,2000  33673
# 331  332  2020-12-28T00:00:00  TERCEIRA PONTE  ...        38200   76139,7000  33674
# 332  333  2020-12-29T00:00:00  TERCEIRA PONTE  ...        39697   79068,1500  33675
# 333  334  2020-12-30T00:00:00  TERCEIRA PONTE  ...        40252   80049,9000  33676
# 334  335  2020-12-31T00:00:00  TERCEIRA PONTE  ...        29282   58684,5000  33677
#
# [335 rows x 16 columns]
